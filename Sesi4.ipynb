# %% [markdown]
# <a href="https://colab.research.google.com/github/Hyphen-14/Scientific-Computing/blob/Session4/Sesi4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# #BISECTION

# %%
def my_bisection (f, a, b, tol) :

 if np.sign(f(a)) == np.sign(f(b)):
    raise Exception("The scalars a and b do not bound a root")

#midpoint
 m = (a+b)/2

 if np.abs(f(m)) < tol:
   return m
 elif np.sign(f(a)) == np.sign(f(m)):
   return my_bisection(f, m, b, tol)
 elif np.sign(f(b)) == np.sign(f(m)):
   return my_bisection(f, a, m, tol)

# %%
f = lambda x: x**2 - 2

r1 = my_bisection(f, 0, 2, 0.1)
print ("r1 =", r1)
r01 = my_bisection(f, 0, 2, 0.01)
print("r01 =", r01)

print ("f(r1) =", f(r1))
print ("f(r01) =", f(r01))
# Out:
# r1 = 1.4375
# r01 = 1.4140625
# f(r1) = 0.06640625
# f(r01) = -0.00042724609375

# %% [markdown]
# #NEWTON

# %%
f = lambda x: x**2 -2
f_prime = lambda x: 2*x
newton_raphson = 1.4 - (f(1.4)) / (f_prime(1.4))

print("newton_raphson =", newton_raphson)
print("sqrt(2) =", np.sqrt(2))
# Out:
# newton_raphson = 1.4142857142857144
# sqrt(2) = 1.4142135623730951

# %%
def my_newton (f, df, x0, tol):
  if abs(f(x0)) < tol:
    return x0
  else:
    return my_newton(f, df, x0 - f(x0)/df(x0), tol)

# %%
estimate = my_newton(f, f_prime, 1.5, 1e-6)
print("estimate =", estimate)
print("sqrt(2) =", np.sqrt(2))
# Out:
# estimate = 1.4142135623746899
# sqrt(2) = 1.4142135623730951

# %% [markdown]
# #Latihan Soal

# %% [markdown]
# Bisection
#
#
# *   f(x) = x^3 + x -1
# *   int [0, 1]
# *   |0| = 0,001

# %%
f = lambda x: x**3 + x - 1
r1 = my_bisection(f, 0, 1, 0.001)
print ("r1 =", r1)
# Out:
# r1 = 0.6826171875

# %% [markdown]
# Newton
#
# *   f(x) = x^2 - ln(x+2)
# *   X0 = 1
# *   tol = 0,001

# %%
f = lambda x: x**2 - np.log(x+2)
f_prime = lambda x: 2*x - 1/(x+2)
estimate = my_newton(f, f_prime, 1, 1e-6)
print("estimate =", estimate)
print("sqrt(2) =", np.sqrt(2))
# Out:
# estimate = 1.0571035499984363
# sqrt(2) = 1.4142135623730951

# %% [markdown]
# #MODUL

# %% [markdown]
# ###Bisection

# %%
def my_bisection (f, a, b, tol) :

 if np.sign(f(a)) == np.sign(f(b)):
    raise Exception("The scalars a and b do not bound a root")

#midpoint
 m = (a+b)/2

 if np.abs(f(m)) < tol:
   return m
 elif np.sign(f(a)) == np.sign(f(m)):
   return my_bisection(f, m, b, tol)
 elif np.sign(f(b)) == np.sign(f(m)):
   return my_bisection(f, a, m, tol)

# %% [markdown]
# * Soal 1
# *  f(x) = x^3 - 3x^2 + 2x
# *  [a, b] = [1, 2]
# *  tol = 0,01

# %%
f = lambda x: x**3 - 3*x**2 + 2*x
r1 = my_bisection(f, 1.1,2, 0.01)
print ("r1 =", r1)
# Out:
# r1 = 1.996484375

# %% [markdown]
# * Soal 2
# *  f(x) = sin(x) - x  \\pakai np.sin
# *  [a, b] = [0, 1]
# *  tol = 0,001

# %%
f = lambda x: np.sin(x) - x
r1 = my_bisection(f, 0, 1, 0.001)
print ("r1 =", r1)
# Out:
# r1 = 0.125

# %% [markdown]
# ###Newton - Raphson

# %% [markdown]
# Soal 1
# * f(x) = x^3 - 3x^2 + 2x
# * x0 = 1,5
# * 0,01

# %%
f = lambda x: x**3 - 3*x**2 + 2*x
f_prime = lambda x: 3*x**2 - 6*x + 2
newton_raphson = 1.4 - (f(1.4)) / (f_prime(1.4))

print("newton_raphson =", newton_raphson)
print("sqrt(2) =", np.sqrt(2))
# Out:
# newton_raphson = 0.7538461538461535
# sqrt(2) = 1.4142135623730951

# %%
def my_newton (f, df, x0, tol):
  if abs(f(x0)) < tol:
    return x0
  else:
    return my_newton(f, df, x0 - f(x0)/df(x0), tol)

# %%
estimate = my_newton(f, f_prime, 1.5, 1e-6)
print("estimate =", estimate)
print("sqrt(2) =", np.sqrt(2))
# Out:
# estimate = 0.0
# sqrt(2) = 1.4142135623730951

# %% [markdown]
# Soal 2
# * f(x) = e^x - 2x //Pakai np.exp
# * x0 = 1
# * tol = 0,001

# %%
f = lambda x: np.exp(x) - 2*x
f_prime = lambda x: np.exp(x) - 2

estimate = my_newton(f, f_prime, 1, 1)
print("estimate =", estimate)
# Out:
# estimate = 1

# %% [markdown]
# Note : Jika tol nya 0,001 menyebabkan kode eror. sehingga saya ganti menjadi 1
